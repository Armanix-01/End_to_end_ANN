# %%
import pandas as pd
input_data = pd.DataFrame({
    
    "CreditScore": [600],
    "Geography": ['France'],
    'Gender': ['Male'],
    "Age": [40],
    'Tenure':[3], 
    'Balance': [60000],
    "NumOfProducts": [2],
    "HasCrCard": [1],
    "IsActiveMember": [1],
    "EstimatedSalary": [50000]
}

)
